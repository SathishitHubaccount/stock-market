# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("/kaggle/input/stock-price/BHARTIARTL.NS.csv")

# %%
df
df.drop('Date', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Open         10
# High         10
# Low          10
# Close        10
# Adj Close    10
# Volume       10
# dtype: int64

# %%
df
# Out:
#             Open        High         Low       Close   Adj Close     Volume
# 0      10.719732   10.719732   10.352461   10.398370    9.747535   183173.0
# 1      10.559051   10.673823   10.329506   10.398370    9.747535   598304.0
# 2      10.650869   11.018140   10.329506   10.352461    9.704500   582614.0
# 3      10.444278   10.559051   10.145870   10.191779    9.553876   292522.0
# 4      10.168825   10.283597   10.122916   10.145870    9.510840   366967.0
# ...          ...         ...         ...         ...         ...        ...
# 5025  750.000000  759.450012  739.150024  757.250000  757.250000  9306857.0
# 5026  754.950012  759.799988  748.799988  754.799988  754.799988  3566109.0
# 5027  760.000000  766.000000  755.150024  756.950012  756.950012  5332221.0
# 5028  761.000000  763.200012  753.150024  756.700012  756.700012  2680654.0
# 5029  758.000000  765.799988  756.849976  763.549988  763.549988  2454948.0
#
# [5030 rows x 6 columns]

# %%
df = df.dropna()
df
df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
x = df[['Open', 'High', 'Low', 'Volume']]  
y = df['Adj Close'] 
x,y
# Out:
# (            Open        High         Low     Volume
#  0      10.719732   10.719732   10.352461   183173.0
#  1      10.559051   10.673823   10.329506   598304.0
#  2      10.650869   11.018140   10.329506   582614.0
#  3      10.444278   10.559051   10.145870   292522.0
#  4      10.168825   10.283597   10.122916   366967.0
#  ...          ...         ...         ...        ...
#  5025  750.000000  759.450012  739.150024  9306857.0
#  5026  754.950012  759.799988  748.799988  3566109.0
#  5027  760.000000  766.000000  755.150024  5332221.0
#  5028  761.000000  763.200012  753.150024  2680654.0
#  5029  758.000000  765.799988  756.849976  2454948.0
#
#  [5020 rows x 4 columns],
#  0         9.747535
#  1         9.747535
#  2         9.704500
#  3         9.553876
#  4         9.510840
#             ...
#  5025    757.250000
#  5026    754.799988
#  5027    756.950012
#  5028    756.700012
#  5029    763.549988
#  Name: Adj Close, Length: 5020, dtype: float64)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
df=scaler.fit_transform(df)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=2)

# %% [raw]
# df

# %%
from sklearn.linear_model import LinearRegression as SVC
model=SVC()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R2 Score (accuracy):", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 66.3326038855898
# Mean Absolute Error: 6.597547029086872
# R2 Score (accuracy): 0.997781415024539
